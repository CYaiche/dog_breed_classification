# %%
# %load_ext autoreload
# %autoreload 2
import os
import numpy as np 
from common_params import data_dir
from common_img_functions import read_img
from common_plots import plot_img
import tensorflow as tf

# %%
test_img = read_img(os.path.join(data_dir , "extracted\\test\\n02085936-Maltese_dog\\n02085936_233_0.jpg"))
test_imge = np.expand_dims(test_img, axis=0)

# %%
plot_img(test_img,correct_color=True)

# %%
test_imge.shape
# Out:
# (1, 224, 224, 3)

# %%
data_augmentation = tf.keras.preprocessing.image.ImageDataGenerator(
    horizontal_flip=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
)

# %%
test = data_augmentation.flow(test_imge)

# %%
test

# %%
import itertools
from common_plots import display_images

# %%
N, M = 4, 4

cnt = 0 
img_list = []
titles= []
for i, j in itertools.product(range(N), range(M)):
    img = test.next()
    img_list.append(img[0].astype("uint8"))
    cnt = cnt + 1 
    
display_images(img_list, N, M,from_path=False,correct_color=True)
